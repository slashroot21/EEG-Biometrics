# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
import re
from matplotlib import pyplot as plt
import scipy.io as sio
import numpy as np
import pickle as pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from scipy import signal
import scipy.io
import os
import math

import tensorflow as tf
import keras
from tensorflow.keras.utils import to_categorical
# from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from keras.models import Sequential, load_model
from keras.layers import Activation, Dropout, Flatten, Dense, LSTM, Conv2D, MaxPooling2D, RepeatVector
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_path = '/content/drive/My Drive/Major/BED_dataset_RAW_PARSED/'

# %%
def load_eeg_data(directory):
    data = []
    labels = []

    for filename in os.listdir(directory):
        if filename.endswith('.mat'):
            filepath = os.path.join(directory, filename)

            mat_contents = scipy.io.loadmat(filepath)
            recordings = mat_contents['recording']

            recordings = recordings[:30208, 2:-1]
            recordings = recordings.T

            data.append(recordings)

            # Extract label from filename
            start_index = filename.index('s') + 1
            end_index = filename.index('_')
            # Extract the substring between 's' and '_'
            number = filename[start_index:end_index]
            person_id = int(number) # Convert the extracted number to an integer

            label = person_id - 1
            labels.append(label)

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

# %%
eeg_data, labels = load_eeg_data(dataset_path)

print("EEG data shape:", eeg_data.shape)
print("Labels shape:", labels.shape)
# Out:
# EEG data shape: (63, 14, 30208)
# Labels shape: (63,)

# %%
eeg_Label = []
for i in labels:
    for j in range (0,14):
        eeg_Label.append(i)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(eeg_Label)

y.shape
# Out:
# (882, 21)

# %%
import functools
def combine_dims(a, i=0, n=1):
  s = list(a.shape)
  combined = functools.reduce(lambda x,y: x*y, s[i:i+n+1])
  return np.reshape(a, s[:i] + [combined] + s[i+n+1:])

# %%
eeg_Data = combine_dims(np.array(eeg_data), 0)

eeg_Data.shape
# Out:
# (882, 30208)

# %%
fs = 256

size_dataset = len(eeg_Data)
nperseg = 512
noverlap = 256
f_size = math.ceil(((nperseg + 1)/2))
t_size = int((eeg_Data[0].size - noverlap ) / (nperseg - noverlap))
X_full = np.ndarray(shape=(size_dataset, f_size, t_size, 3))

for i in range(0, size_dataset):
  for j in range(0,3):
    X = eeg_Data[i]
    f, t, Sxx = spectrogram(X, fs, nperseg = nperseg, noverlap = noverlap, mode='psd')
    X_full[i, :, :, j] = Sxx

# %%
X_full.shape
# Out:
# (882, 257, 117, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.2, random_state=42)

X_train /= 255
X_test /= 255

# %%
num_classes = 21

input_shape = (X_train.shape[1],X_train.shape[2],X_train.shape[3])
input_shape
# Out:
# (257, 117, 3)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calculate class weights based on imbalance ratio
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)

# Convert class_weights array to a dictionary
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, RepeatVector, LSTM, Dense, Layer
import keras.backend as K

class Attention(Layer):
    def __init__(self, **kwargs):
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[0][-1], 1), initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(input_shape[0][1], 1), initializer="zeros")
        super(Attention, self).build(input_shape)

    def call(self, x):
        lstm_output, _, _ = x
        et = K.squeeze(K.tanh(K.dot(lstm_output, self.W) + self.b), axis=-1)
        at = K.softmax(et)
        at = K.expand_dims(at, axis=-1)
        output = lstm_output * at
        return K.sum(output, axis=1)

    def compute_output_shape(self, input_shape):
        return (input_shape[0][0], input_shape[0][-1])

# Define the model with the corrected Attention layer
inputs = Input(shape=input_shape)
x = Conv2D(32, (3, 3), strides=(1, 1), activation='relu')(inputs)
x = MaxPooling2D((2, 2), strides=(2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Dropout(0.1)(x)
x = Flatten()(x)
x = RepeatVector(4)(x)
lstm_output = LSTM(256, return_sequences=True, return_state=True, dropout=0.2)(x)
attention_output = Attention()(lstm_output)
dense_output = Dense(128, activation='relu')(attention_output)
outputs = Dense(num_classes, activation='softmax')(dense_output)
model = Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 257, 117, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 255, 115, 32)         896       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 127, 57, 32)          0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 55, 64)          18496     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 27, 64)           0         ['conv2d_1[0][0]']
#  g2D)
#
#  dropout (Dropout)           (None, 62, 27, 64)           0         ['max_pooling2d_1[0][0]']
#
#  flatten (Flatten)           (None, 107136)               0         ['dropout[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 4, 107136)            0         ['flatten[0][0]']
#  r)
#
#  lstm (LSTM)                 [(None, 4, 256),             1099704   ['repeat_vector[0][0]']
#                               (None, 256),                32
#                               (None, 256)]
#
#  attention (Attention)       (None, 256)                  260       ['lstm[0][0]',
#                                                                      'lstm[0][1]',
#                                                                      'lstm[0][2]']
#
#  dense (Dense)               (None, 128)                  32896     ['attention[0][0]']
#
#  dense_1 (Dense)             (None, 21)                   2709      ['dense[0][0]']
#
# ==================================================================================================
# Total params: 110025689 (419.71 MB)
# Trainable params: 110025689 (419.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer ="Adam", loss =keras.losses.categorical_crossentropy, metrics=['accuracy'])
m=model.fit(X_train, y_train,epochs=100,batch_size=128,verbose=1,validation_data=(X_test, y_test), class_weight=class_weights_dict, callbacks =[es, mc])
# Out:
# Epoch 1/100
# 6/6 [==============================] - ETA: 0s - loss: 2.5155 - accuracy: 0.3376
# Epoch 1: val_accuracy improved from -inf to 0.55367, saving model to best_model.h5
# 6/6 [==============================] - 141s 23s/step - loss: 2.5155 - accuracy: 0.3376 - val_loss: 1.8256 - val_accuracy: 0.5537
# Epoch 2/100
# 6/6 [==============================] - ETA: 0s - loss: 1.3860 - accuracy: 0.6979
# Epoch 2: val_accuracy improved from 0.55367 to 0.72316, saving model to best_model.h5
# 6/6 [==============================] - 143s 24s/step - loss: 1.3860 - accuracy: 0.6979 - val_loss: 1.2318 - val_accuracy: 0.7232
# Epoch 3/100
# 6/6 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.8397
# Epoch 3: val_accuracy improved from 0.72316 to 0.81356, saving model to best_model.h5
# 6/6 [==============================] - 148s 25s/step - loss: 0.7637 - accuracy: 0.8397 - val_loss: 0.8138 - val_accuracy: 0.8136
# Epoch 4/100
# 6/6 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8950
# Epoch 4: val_accuracy improved from 0.81356 to 0.81921, saving model to best_model.h5
# 6/6 [==============================] - 141s 23s/step - loss: 0.4408 - accuracy: 0.8950 - val_loss: 0.6665 - val_accuracy: 0.8192
# Epoch 5/100
# 6/6 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9546
# Epoch 5: val_accuracy improved from 0.81921 to 0.85311, saving model to best_model.h5
# 6/6 [==============================] - 146s 25s/step - loss: 0.2537 - accuracy: 0.9546 - val_loss: 0.5124 - val_accuracy: 0.8531
# Epoch 6/100
# 6/6 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9631
# Epoch 6: val_accuracy did not improve from 0.85311
# 6/6 [==============================] - 132s 22s/step - loss: 0.1631 - accuracy: 0.9631 - val_loss: 0.4630 - val_accuracy: 0.8418
# Epoch 7/100
# 6/6 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9801
# Epoch 7: val_accuracy improved from 0.85311 to 0.85876, saving model to best_model.h5
# 6/6 [==============================] - 141s 23s/step - loss: 0.1141 - accuracy: 0.9801 - val_loss: 0.4216 - val_accuracy: 0.8588
# Epoch 8/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9773
# Epoch 8: val_accuracy did not improve from 0.85876
# 6/6 [==============================] - 142s 24s/step - loss: 0.0885 - accuracy: 0.9773 - val_loss: 0.4401 - val_accuracy: 0.8588
# Epoch 9/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9801
# Epoch 9: val_accuracy did not improve from 0.85876
# 6/6 [==============================] - 137s 23s/step - loss: 0.0737 - accuracy: 0.9801 - val_loss: 0.4267 - val_accuracy: 0.8531
# Epoch 10/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0599 - accuracy: 0.9858
# Epoch 10: val_accuracy did not improve from 0.85876
# 6/6 [==============================] - 133s 22s/step - loss: 0.0599 - accuracy: 0.9858 - val_loss: 0.4158 - val_accuracy: 0.8531
# Epoch 11/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9844
# Epoch 11: val_accuracy improved from 0.85876 to 0.86441, saving model to best_model.h5
# 6/6 [==============================] - 145s 25s/step - loss: 0.0544 - accuracy: 0.9844 - val_loss: 0.4116 - val_accuracy: 0.8644
# Epoch 12/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9858
# Epoch 12: val_accuracy did not improve from 0.86441
# 6/6 [==============================] - 140s 23s/step - loss: 0.0495 - accuracy: 0.9858 - val_loss: 0.4122 - val_accuracy: 0.8588
# Epoch 13/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9844
# Epoch 13: val_accuracy did not improve from 0.86441
# 6/6 [==============================] - 133s 22s/step - loss: 0.0460 - accuracy: 0.9844 - val_loss: 0.4139 - val_accuracy: 0.8644
# Epoch 14/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0424 - accuracy: 0.9858
# Epoch 14: val_accuracy did not improve from 0.86441
# 6/6 [==============================] - 137s 23s/step - loss: 0.0424 - accuracy: 0.9858 - val_loss: 0.4210 - val_accuracy: 0.8644
# Epoch 15/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9901
# Epoch 15: val_accuracy improved from 0.86441 to 0.87571, saving model to best_model.h5
# 6/6 [==============================] - 143s 24s/step - loss: 0.0374 - accuracy: 0.9901 - val_loss: 0.4315 - val_accuracy: 0.8757
# Epoch 16/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9957
# Epoch 16: val_accuracy did not improve from 0.87571
# 6/6 [==============================] - 133s 22s/step - loss: 0.0349 - accuracy: 0.9957 - val_loss: 0.4404 - val_accuracy: 0.8644
# Epoch 17/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0337 - accuracy: 0.9915
# Epoch 17: val_accuracy did not improve from 0.87571
# 6/6 [==============================] - 141s 22s/step - loss: 0.0337 - accuracy: 0.9915 - val_loss: 0.4352 - val_accuracy: 0.8757
# Epoch 18/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9929
# Epoch 18: val_accuracy improved from 0.87571 to 0.88701, saving model to best_model.h5
# 6/6 [==============================] - 151s 26s/step - loss: 0.0309 - accuracy: 0.9929 - val_loss: 0.4099 - val_accuracy: 0.8870
# Epoch 19/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9901
# Epoch 19: val_accuracy did not improve from 0.88701
# 6/6 [==============================] - 137s 22s/step - loss: 0.0331 - accuracy: 0.9901 - val_loss: 0.4097 - val_accuracy: 0.8870
# Epoch 20/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9915
# Epoch 20: val_accuracy improved from 0.88701 to 0.89266, saving model to best_model.h5
# 6/6 [==============================] - 147s 25s/step - loss: 0.0293 - accuracy: 0.9915 - val_loss: 0.4092 - val_accuracy: 0.8927
# Epoch 21/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9901
# Epoch 21: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 142s 24s/step - loss: 0.0279 - accuracy: 0.9901 - val_loss: 0.3921 - val_accuracy: 0.8927
# Epoch 22/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9929
# Epoch 22: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0272 - accuracy: 0.9929 - val_loss: 0.4037 - val_accuracy: 0.8870
# Epoch 23/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9915
# Epoch 23: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 134s 22s/step - loss: 0.0278 - accuracy: 0.9915 - val_loss: 0.4214 - val_accuracy: 0.8870
# Epoch 24/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9972
# Epoch 24: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 134s 22s/step - loss: 0.0284 - accuracy: 0.9972 - val_loss: 0.4386 - val_accuracy: 0.8814
# Epoch 25/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9986
# Epoch 25: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 143s 24s/step - loss: 0.0253 - accuracy: 0.9986 - val_loss: 0.4315 - val_accuracy: 0.8701
# Epoch 26/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9872
# Epoch 26: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0277 - accuracy: 0.9872 - val_loss: 0.4355 - val_accuracy: 0.8701
# Epoch 27/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0307 - accuracy: 0.9844
# Epoch 27: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 137s 23s/step - loss: 0.0307 - accuracy: 0.9844 - val_loss: 0.4410 - val_accuracy: 0.8588
# Epoch 28/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9887
# Epoch 28: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0282 - accuracy: 0.9887 - val_loss: 0.4421 - val_accuracy: 0.8644
# Epoch 29/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9901
# Epoch 29: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 133s 22s/step - loss: 0.0266 - accuracy: 0.9901 - val_loss: 0.4285 - val_accuracy: 0.8701
# Epoch 30/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9901
# Epoch 30: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 145s 24s/step - loss: 0.0256 - accuracy: 0.9901 - val_loss: 0.4216 - val_accuracy: 0.8757
# Epoch 31/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9872
# Epoch 31: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0251 - accuracy: 0.9872 - val_loss: 0.4103 - val_accuracy: 0.8701
# Epoch 32/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9858
# Epoch 32: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 135s 23s/step - loss: 0.0255 - accuracy: 0.9858 - val_loss: 0.4159 - val_accuracy: 0.8701
# Epoch 33/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9858
# Epoch 33: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 133s 22s/step - loss: 0.0253 - accuracy: 0.9858 - val_loss: 0.4160 - val_accuracy: 0.8644
# Epoch 34/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9887
# Epoch 34: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 140s 23s/step - loss: 0.0250 - accuracy: 0.9887 - val_loss: 0.4136 - val_accuracy: 0.8701
# Epoch 35/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9887
# Epoch 35: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 135s 22s/step - loss: 0.0272 - accuracy: 0.9887 - val_loss: 0.3910 - val_accuracy: 0.8701
# Epoch 36/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9887
# Epoch 36: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 138s 23s/step - loss: 0.0242 - accuracy: 0.9887 - val_loss: 0.4096 - val_accuracy: 0.8701
# Epoch 37/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9872
# Epoch 37: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 135s 22s/step - loss: 0.0248 - accuracy: 0.9872 - val_loss: 0.4031 - val_accuracy: 0.8701
# Epoch 38/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9915
# Epoch 38: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 0.4090 - val_accuracy: 0.8701
# Epoch 39/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9858
# Epoch 39: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 141s 22s/step - loss: 0.0242 - accuracy: 0.9858 - val_loss: 0.3946 - val_accuracy: 0.8701
# Epoch 40/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 0.9901
# Epoch 40: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 135s 22s/step - loss: 0.0243 - accuracy: 0.9901 - val_loss: 0.3771 - val_accuracy: 0.8814
# Epoch 41/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9887
# Epoch 41: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 136s 23s/step - loss: 0.0235 - accuracy: 0.9887 - val_loss: 0.3903 - val_accuracy: 0.8644
# Epoch 42/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9901
# Epoch 42: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 139s 23s/step - loss: 0.0246 - accuracy: 0.9901 - val_loss: 0.3999 - val_accuracy: 0.8644
# Epoch 43/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9901
# Epoch 43: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 132s 22s/step - loss: 0.0266 - accuracy: 0.9901 - val_loss: 0.4092 - val_accuracy: 0.8870
# Epoch 44/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9915
# Epoch 44: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 133s 22s/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.4244 - val_accuracy: 0.8870
# Epoch 45/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9943
# Epoch 45: val_accuracy did not improve from 0.89266
# 6/6 [==============================] - 132s 22s/step - loss: 0.0209 - accuracy: 0.9943 - val_loss: 0.4237 - val_accuracy: 0.8870
# Epoch 46/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.9872
# Epoch 46: val_accuracy improved from 0.89266 to 0.89831, saving model to best_model.h5
# 6/6 [==============================] - 158s 27s/step - loss: 0.0258 - accuracy: 0.9872 - val_loss: 0.4198 - val_accuracy: 0.8983
# Epoch 47/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9901
# Epoch 47: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 133s 22s/step - loss: 0.0212 - accuracy: 0.9901 - val_loss: 0.4004 - val_accuracy: 0.8870
# Epoch 48/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9901
# Epoch 48: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 135s 22s/step - loss: 0.0224 - accuracy: 0.9901 - val_loss: 0.3849 - val_accuracy: 0.8757
# Epoch 49/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9972
# Epoch 49: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 131s 22s/step - loss: 0.0203 - accuracy: 0.9972 - val_loss: 0.3869 - val_accuracy: 0.8983
# Epoch 50/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9929
# Epoch 50: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 133s 22s/step - loss: 0.0216 - accuracy: 0.9929 - val_loss: 0.3737 - val_accuracy: 0.8983
# Epoch 51/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9872
# Epoch 51: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 137s 23s/step - loss: 0.0256 - accuracy: 0.9872 - val_loss: 0.4449 - val_accuracy: 0.8701
# Epoch 52/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9858
# Epoch 52: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 135s 22s/step - loss: 0.0374 - accuracy: 0.9858 - val_loss: 0.4159 - val_accuracy: 0.8757
# Epoch 53/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0421 - accuracy: 0.9887
# Epoch 53: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 134s 22s/step - loss: 0.0421 - accuracy: 0.9887 - val_loss: 0.4410 - val_accuracy: 0.8757
# Epoch 54/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9858
# Epoch 54: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 136s 23s/step - loss: 0.0560 - accuracy: 0.9858 - val_loss: 0.3703 - val_accuracy: 0.8983
# Epoch 55/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9887
# Epoch 55: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 146s 24s/step - loss: 0.0400 - accuracy: 0.9887 - val_loss: 0.4069 - val_accuracy: 0.8927
# Epoch 56/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9887
# Epoch 56: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 138s 22s/step - loss: 0.0300 - accuracy: 0.9887 - val_loss: 0.4401 - val_accuracy: 0.8814
# Epoch 57/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9887
# Epoch 57: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 133s 22s/step - loss: 0.0250 - accuracy: 0.9887 - val_loss: 0.4068 - val_accuracy: 0.8701
# Epoch 58/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9929
# Epoch 58: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 137s 23s/step - loss: 0.0237 - accuracy: 0.9929 - val_loss: 0.4327 - val_accuracy: 0.8757
# Epoch 59/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9887
# Epoch 59: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 131s 22s/step - loss: 0.0231 - accuracy: 0.9887 - val_loss: 0.4826 - val_accuracy: 0.8870
# Epoch 60/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9915
# Epoch 60: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 142s 24s/step - loss: 0.0246 - accuracy: 0.9915 - val_loss: 0.4672 - val_accuracy: 0.8870
# Epoch 61/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9915
# Epoch 61: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 135s 23s/step - loss: 0.0222 - accuracy: 0.9915 - val_loss: 0.4214 - val_accuracy: 0.8870
# Epoch 62/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9943
# Epoch 62: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 134s 22s/step - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.4143 - val_accuracy: 0.8927
# Epoch 63/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9943
# Epoch 63: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 139s 23s/step - loss: 0.0198 - accuracy: 0.9943 - val_loss: 0.4230 - val_accuracy: 0.8983
# Epoch 64/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9986
# Epoch 64: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 138s 23s/step - loss: 0.0152 - accuracy: 0.9986 - val_loss: 0.4315 - val_accuracy: 0.8983
# Epoch 65/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9957
# Epoch 65: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 136s 22s/step - loss: 0.0162 - accuracy: 0.9957 - val_loss: 0.4511 - val_accuracy: 0.8870
# Epoch 66/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9957
# Epoch 66: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 133s 22s/step - loss: 0.0146 - accuracy: 0.9957 - val_loss: 0.4586 - val_accuracy: 0.8814
# Epoch 67/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9986
# Epoch 67: val_accuracy did not improve from 0.89831
# 6/6 [==============================] - 135s 22s/step - loss: 0.0137 - accuracy: 0.9986 - val_loss: 0.4568 - val_accuracy: 0.8814
# Epoch 68/100
# 2/6 [=========>....................] - ETA: 1:26 - loss: 0.0160 - accuracy: 0.9961

# %%
saved_model = load_model('best_model.h5')

# %%
_, train_f1 = saved_model.evaluate(X_train, y_train, verbose=0)
_, test_f1 = saved_model.evaluate(X_test, y_test, verbose=0)

print(test_f1)

# %%
import matplotlib.pyplot as plt
plt.plot(m.history['accuracy'])
plt.plot(m.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
y_test1=np.argmax(y_test, axis=1)

y_pred_saved = saved_model.predict(X_test)
y_pred_saved=np.argmax(y_pred_saved,axis=1)

# %%
from sklearn import metrics
print(metrics.classification_report(y_test1,y_pred_saved))

# %%
saved_model = load_model('best_model.h5')
saved_model.save('/content/drive/My Drive/saved_models/BED_14.h5')
