# %%
# !pip install mne
# Out:
# Collecting mne
#   Downloading mne-1.6.1-py3-none-any.whl (8.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 27.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.25.2)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)
# Installing collected packages: mne
# Successfully installed mne-1.6.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import os
import mne
import re
from matplotlib import pyplot as plt
import scipy.io as sio
import numpy as np
import pickle as pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from scipy.signal import spectrogram
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from scipy import signal
import os
import math

import tensorflow as tf
import keras
from tensorflow.keras.utils import to_categorical
# from keras.wrappers.scikit_learn import KerasClassifier
import keras.backend as K
from keras.models import Sequential, load_model
from keras.layers import Activation, Dropout, Flatten, Dense, LSTM, Conv2D, MaxPooling2D, RepeatVector
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_path = '/content/drive/My Drive/Major/auditory-evoked-potential-eeg-biometric-dataset-1.0.0/Filtered_Data/'
channel_names = ['P4', 'Cz', 'F8', 'T7']  # Specify the EEG channel names

# %%
def load_eeg_data(directory, channel_names):
    data = []
    labels = []

    for filename in os.listdir(directory):
        if filename.endswith('.csv'):
            filepath = os.path.join(directory, filename)

            df = pd.read_csv(filepath)

            num_rows = len(df)
            # If the number of rows is less than the specified maximum
            if num_rows < 24000:
                print(f"Skipping file {filename} as it doesn't have enough rows.")
                continue
            df = df.head(23800)

            eeg_data_per_file = []
            for channel_name in channel_names:
                if channel_name in df.columns:
                    eeg_data_per_file.append(df[channel_name].values)
                else:
                    print(f"Column '{channel_name}' not found in file {filename}. Skipping...")
                    eeg_data_per_file = None
                    break

            if eeg_data_per_file is None:
                continue

            eeg_data_per_file = np.array(eeg_data_per_file)  # Convert to numpy array
            data.append(eeg_data_per_file)

            # Extract label from filename
            person_id = 0
            match = re.search(r's(\d+)_ex', filename)
            if match:
                person_id = int(match.group(1))  # Convert the extracted number to an integer
            else:
                print("No match found.")
            label = person_id - 1
            # label = np.zeros(20, dtype=bool)  # 20 classes (persons)
            # label[person_id - 1] = 1
            labels.append(label)

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

# %%
eeg_data, labels = load_eeg_data(dataset_path, channel_names)

print("EEG data shape:", eeg_data.shape)
print("Labels shape:", labels.shape)
# Out:
# Skipping file s03_ex06.csv as it doesn't have enough rows.
# Skipping file s20_ex01_s03.csv as it doesn't have enough rows.
# Skipping file s19_ex01_s03.csv as it doesn't have enough rows.
# EEG data shape: (237, 4, 23800)
# Labels shape: (237,)

# %%
eeg_Label = []
for i in labels:
    for j in range (0,4):
        eeg_Label.append(i)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(eeg_Label)

y.shape
# Out:
# (948, 20)

# %%
import functools
def combine_dims(a, i=0, n=1):
  s = list(a.shape)
  combined = functools.reduce(lambda x,y: x*y, s[i:i+n+1])
  return np.reshape(a, s[:i] + [combined] + s[i+n+1:])

# %%
eeg_Data = combine_dims(np.array(eeg_data), 0)

eeg_Data.shape
# Out:
# (948, 23800)

# %%
fs = 200

size_dataset = len(eeg_Data)
nperseg = 400
noverlap = 200
f_size = math.ceil(((nperseg + 1)/2))
t_size = int((eeg_Data[0].size - noverlap ) / (nperseg - noverlap))
X_full = np.ndarray(shape=(size_dataset, f_size, t_size, 3))

for i in range(0, size_dataset):
  for j in range(0,3):
    X = eeg_Data[i]
    f, t, Sxx = spectrogram(X, fs, nperseg = nperseg, noverlap = noverlap, mode='psd')
    X_full[i, :, :, j] = Sxx

# %%
X_full = np.array(X_full)

X_full.shape
# Out:
# (948, 201, 118, 3)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_full, y, test_size=0.2, random_state=42)

X_train /= 255
X_test /= 255

# %%
num_classes = 20

input_shape = (X_train.shape[1],X_train.shape[2],X_train.shape[3])
input_shape
# Out:
# (201, 118, 3)

# %%
from sklearn.utils.class_weight import compute_class_weight

# Calculate class weights based on imbalance ratio
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(labels), y=labels)

# Convert class_weights array to a dictionary
class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3),
          strides=(1, 1),
          activation='relu',
          input_shape=input_shape))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))

model.add(Conv2D(64, (3, 3),
          activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())

model.add(RepeatVector(4))

model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(128))
model.add(Dropout(0.2))

model.add(Dense(64, activation="relu"))
model.add(Dropout(0.2))


model.add(Dense(num_classes, activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 199, 116, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 99, 58, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 97, 56, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 28, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 48, 28, 64)        0
#
#  flatten (Flatten)           (None, 86016)             0
#
#  repeat_vector (RepeatVecto  (None, 4, 86016)          0
#  r)
#
#  lstm (LSTM)                 (None, 4, 256)            88343552
#
#  dropout_1 (Dropout)         (None, 4, 256)            0
#
#  lstm_1 (LSTM)               (None, 128)               197120
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 20)                1300
#
# =================================================================
# Total params: 88569620 (337.87 MB)
# Trainable params: 88569620 (337.87 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer ="Adam", loss =keras.losses.categorical_crossentropy, metrics=['accuracy'])
m=model.fit(X_train, y_train,epochs=100,batch_size=256,verbose=1,validation_data=(X_test, y_test), class_weight=class_weights_dict, callbacks =[es, mc])
# Out:
# Epoch 1/100
# 3/3 [==============================] - ETA: 0s - loss: 2.9861 - accuracy: 0.0541
# Epoch 1: val_accuracy improved from -inf to 0.10000, saving model to best_model.h5
# 3/3 [==============================] - 100s 34s/step - loss: 2.9861 - accuracy: 0.0541 - val_loss: 2.9427 - val_accuracy: 0.1000
# Epoch 2/100
# 3/3 [==============================] - ETA: 0s - loss: 2.9257 - accuracy: 0.0897
# Epoch 2: val_accuracy improved from 0.10000 to 0.10526, saving model to best_model.h5
# 3/3 [==============================] - 87s 30s/step - loss: 2.9257 - accuracy: 0.0897 - val_loss: 2.8745 - val_accuracy: 0.1053
# Epoch 3/100
# 3/3 [==============================] - ETA: 0s - loss: 2.8436 - accuracy: 0.1253
# Epoch 3: val_accuracy improved from 0.10526 to 0.15789, saving model to best_model.h5
# 3/3 [==============================] - 89s 31s/step - loss: 2.8436 - accuracy: 0.1253 - val_loss: 2.7672 - val_accuracy: 0.1579
# Epoch 4/100
# 3/3 [==============================] - ETA: 0s - loss: 2.7371 - accuracy: 0.1728
# Epoch 4: val_accuracy improved from 0.15789 to 0.17895, saving model to best_model.h5
# 3/3 [==============================] - 94s 33s/step - loss: 2.7371 - accuracy: 0.1728 - val_loss: 2.6136 - val_accuracy: 0.1789
# Epoch 5/100
# 3/3 [==============================] - ETA: 0s - loss: 2.5873 - accuracy: 0.2177
# Epoch 5: val_accuracy improved from 0.17895 to 0.21053, saving model to best_model.h5
# 3/3 [==============================] - 90s 32s/step - loss: 2.5873 - accuracy: 0.2177 - val_loss: 2.4996 - val_accuracy: 0.2105
# Epoch 6/100
# 3/3 [==============================] - ETA: 0s - loss: 2.4243 - accuracy: 0.2731
# Epoch 6: val_accuracy improved from 0.21053 to 0.31053, saving model to best_model.h5
# 3/3 [==============================] - 87s 30s/step - loss: 2.4243 - accuracy: 0.2731 - val_loss: 2.3509 - val_accuracy: 0.3105
# Epoch 7/100
# 3/3 [==============================] - ETA: 0s - loss: 2.2517 - accuracy: 0.3206
# Epoch 7: val_accuracy improved from 0.31053 to 0.32632, saving model to best_model.h5
# 3/3 [==============================] - 92s 33s/step - loss: 2.2517 - accuracy: 0.3206 - val_loss: 2.1686 - val_accuracy: 0.3263
# Epoch 8/100
# 3/3 [==============================] - ETA: 0s - loss: 2.1551 - accuracy: 0.3364
# Epoch 8: val_accuracy improved from 0.32632 to 0.35263, saving model to best_model.h5
# 3/3 [==============================] - 87s 30s/step - loss: 2.1551 - accuracy: 0.3364 - val_loss: 2.0284 - val_accuracy: 0.3526
# Epoch 9/100
# 3/3 [==============================] - ETA: 0s - loss: 1.9799 - accuracy: 0.4077
# Epoch 9: val_accuracy improved from 0.35263 to 0.44737, saving model to best_model.h5
# 3/3 [==============================] - 91s 33s/step - loss: 1.9799 - accuracy: 0.4077 - val_loss: 1.8956 - val_accuracy: 0.4474
# Epoch 10/100
# 3/3 [==============================] - ETA: 0s - loss: 1.8526 - accuracy: 0.4367
# Epoch 10: val_accuracy improved from 0.44737 to 0.48947, saving model to best_model.h5
# 3/3 [==============================] - 90s 32s/step - loss: 1.8526 - accuracy: 0.4367 - val_loss: 1.6945 - val_accuracy: 0.4895
# Epoch 11/100
# 3/3 [==============================] - ETA: 0s - loss: 1.6804 - accuracy: 0.5198
# Epoch 11: val_accuracy improved from 0.48947 to 0.53684, saving model to best_model.h5
# 3/3 [==============================] - 86s 30s/step - loss: 1.6804 - accuracy: 0.5198 - val_loss: 1.5490 - val_accuracy: 0.5368
# Epoch 12/100
# 3/3 [==============================] - ETA: 0s - loss: 1.5005 - accuracy: 0.5778
# Epoch 12: val_accuracy improved from 0.53684 to 0.55789, saving model to best_model.h5
# 3/3 [==============================] - 87s 31s/step - loss: 1.5005 - accuracy: 0.5778 - val_loss: 1.4886 - val_accuracy: 0.5579
# Epoch 13/100
# 3/3 [==============================] - ETA: 0s - loss: 1.3563 - accuracy: 0.6201
# Epoch 13: val_accuracy improved from 0.55789 to 0.56842, saving model to best_model.h5
# 3/3 [==============================] - 88s 31s/step - loss: 1.3563 - accuracy: 0.6201 - val_loss: 1.4311 - val_accuracy: 0.5684
# Epoch 14/100
# 3/3 [==============================] - ETA: 0s - loss: 1.2692 - accuracy: 0.6464
# Epoch 14: val_accuracy improved from 0.56842 to 0.61579, saving model to best_model.h5
# 3/3 [==============================] - 90s 32s/step - loss: 1.2692 - accuracy: 0.6464 - val_loss: 1.2125 - val_accuracy: 0.6158
# Epoch 15/100
# 3/3 [==============================] - ETA: 0s - loss: 1.0897 - accuracy: 0.6953
# Epoch 15: val_accuracy improved from 0.61579 to 0.68947, saving model to best_model.h5
# 3/3 [==============================] - 91s 32s/step - loss: 1.0897 - accuracy: 0.6953 - val_loss: 1.0750 - val_accuracy: 0.6895
# Epoch 16/100
# 3/3 [==============================] - ETA: 0s - loss: 0.9530 - accuracy: 0.7454
# Epoch 16: val_accuracy did not improve from 0.68947
# 3/3 [==============================] - 83s 28s/step - loss: 0.9530 - accuracy: 0.7454 - val_loss: 1.0235 - val_accuracy: 0.6895
# Epoch 17/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8440 - accuracy: 0.7612
# Epoch 17: val_accuracy did not improve from 0.68947
# 3/3 [==============================] - 83s 28s/step - loss: 0.8440 - accuracy: 0.7612 - val_loss: 0.9945 - val_accuracy: 0.6842
# Epoch 18/100
# 3/3 [==============================] - ETA: 0s - loss: 0.8119 - accuracy: 0.7691
# Epoch 18: val_accuracy did not improve from 0.68947
# 3/3 [==============================] - 87s 31s/step - loss: 0.8119 - accuracy: 0.7691 - val_loss: 0.9980 - val_accuracy: 0.6842
# Epoch 19/100
# 3/3 [==============================] - ETA: 0s - loss: 0.7182 - accuracy: 0.8100
# Epoch 19: val_accuracy improved from 0.68947 to 0.73158, saving model to best_model.h5
# 3/3 [==============================] - 95s 34s/step - loss: 0.7182 - accuracy: 0.8100 - val_loss: 0.8896 - val_accuracy: 0.7316
# Epoch 20/100
# 3/3 [==============================] - ETA: 0s - loss: 0.6457 - accuracy: 0.8153
# Epoch 20: val_accuracy improved from 0.73158 to 0.75789, saving model to best_model.h5
# 3/3 [==============================] - 92s 33s/step - loss: 0.6457 - accuracy: 0.8153 - val_loss: 0.7654 - val_accuracy: 0.7579
# Epoch 21/100
# 3/3 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.8615
# Epoch 21: val_accuracy improved from 0.75789 to 0.80526, saving model to best_model.h5
# 3/3 [==============================] - 92s 33s/step - loss: 0.5451 - accuracy: 0.8615 - val_loss: 0.6801 - val_accuracy: 0.8053
# Epoch 22/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4535 - accuracy: 0.8681
# Epoch 22: val_accuracy improved from 0.80526 to 0.82105, saving model to best_model.h5
# 3/3 [==============================] - 86s 30s/step - loss: 0.4535 - accuracy: 0.8681 - val_loss: 0.6240 - val_accuracy: 0.8211
# Epoch 23/100
# 3/3 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8971
# Epoch 23: val_accuracy did not improve from 0.82105
# 3/3 [==============================] - 83s 28s/step - loss: 0.4146 - accuracy: 0.8971 - val_loss: 0.6480 - val_accuracy: 0.8053
# Epoch 24/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3618 - accuracy: 0.9129
# Epoch 24: val_accuracy improved from 0.82105 to 0.84737, saving model to best_model.h5
# 3/3 [==============================] - 95s 34s/step - loss: 0.3618 - accuracy: 0.9129 - val_loss: 0.5657 - val_accuracy: 0.8474
# Epoch 25/100
# 3/3 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.9182
# Epoch 25: val_accuracy improved from 0.84737 to 0.86842, saving model to best_model.h5
# 3/3 [==============================] - 91s 32s/step - loss: 0.3258 - accuracy: 0.9182 - val_loss: 0.4868 - val_accuracy: 0.8684
# Epoch 26/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9274
# Epoch 26: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 84s 29s/step - loss: 0.2832 - accuracy: 0.9274 - val_loss: 0.5148 - val_accuracy: 0.8316
# Epoch 27/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2635 - accuracy: 0.9340
# Epoch 27: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 83s 29s/step - loss: 0.2635 - accuracy: 0.9340 - val_loss: 0.4919 - val_accuracy: 0.8316
# Epoch 28/100
# 3/3 [==============================] - ETA: 0s - loss: 0.2280 - accuracy: 0.9433
# Epoch 28: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 87s 30s/step - loss: 0.2280 - accuracy: 0.9433 - val_loss: 0.4918 - val_accuracy: 0.8474
# Epoch 29/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9670
# Epoch 29: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 83s 28s/step - loss: 0.1745 - accuracy: 0.9670 - val_loss: 0.5141 - val_accuracy: 0.8316
# Epoch 30/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9512
# Epoch 30: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 87s 30s/step - loss: 0.1693 - accuracy: 0.9512 - val_loss: 0.4775 - val_accuracy: 0.8526
# Epoch 31/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9683
# Epoch 31: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 90s 31s/step - loss: 0.1414 - accuracy: 0.9683 - val_loss: 0.4951 - val_accuracy: 0.8526
# Epoch 32/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9736
# Epoch 32: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 84s 28s/step - loss: 0.1386 - accuracy: 0.9736 - val_loss: 0.4997 - val_accuracy: 0.8421
# Epoch 33/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1092 - accuracy: 0.9815
# Epoch 33: val_accuracy did not improve from 0.86842
# 3/3 [==============================] - 85s 29s/step - loss: 0.1092 - accuracy: 0.9815 - val_loss: 0.4053 - val_accuracy: 0.8684
# Epoch 34/100
# 3/3 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9657
# Epoch 34: val_accuracy improved from 0.86842 to 0.88421, saving model to best_model.h5
# 3/3 [==============================] - 93s 33s/step - loss: 0.1224 - accuracy: 0.9657 - val_loss: 0.4412 - val_accuracy: 0.8842
# Epoch 35/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9828
# Epoch 35: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 83s 28s/step - loss: 0.0856 - accuracy: 0.9828 - val_loss: 0.5314 - val_accuracy: 0.8421
# Epoch 36/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9881
# Epoch 36: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 83s 29s/step - loss: 0.0713 - accuracy: 0.9881 - val_loss: 0.4593 - val_accuracy: 0.8789
# Epoch 37/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0849 - accuracy: 0.9855
# Epoch 37: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 84s 29s/step - loss: 0.0849 - accuracy: 0.9855 - val_loss: 0.4628 - val_accuracy: 0.8526
# Epoch 38/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9908
# Epoch 38: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 85s 29s/step - loss: 0.0617 - accuracy: 0.9908 - val_loss: 0.4172 - val_accuracy: 0.8789
# Epoch 39/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0658 - accuracy: 0.9855
# Epoch 39: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 83s 28s/step - loss: 0.0658 - accuracy: 0.9855 - val_loss: 0.4679 - val_accuracy: 0.8737
# Epoch 40/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9934
# Epoch 40: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 83s 28s/step - loss: 0.0552 - accuracy: 0.9934 - val_loss: 0.5709 - val_accuracy: 0.8368
# Epoch 41/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9868
# Epoch 41: val_accuracy did not improve from 0.88421
# 3/3 [==============================] - 90s 31s/step - loss: 0.0620 - accuracy: 0.9868 - val_loss: 0.5659 - val_accuracy: 0.8105
# Epoch 42/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0559 - accuracy: 0.9881
# Epoch 42: val_accuracy improved from 0.88421 to 0.90526, saving model to best_model.h5
# 3/3 [==============================] - 89s 31s/step - loss: 0.0559 - accuracy: 0.9881 - val_loss: 0.4497 - val_accuracy: 0.9053
# Epoch 43/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9881
# Epoch 43: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 85s 29s/step - loss: 0.0488 - accuracy: 0.9881 - val_loss: 0.4444 - val_accuracy: 0.9000
# Epoch 44/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 0.9947
# Epoch 44: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 85s 29s/step - loss: 0.0415 - accuracy: 0.9947 - val_loss: 0.4131 - val_accuracy: 0.8789
# Epoch 45/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9908
# Epoch 45: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 85s 29s/step - loss: 0.0459 - accuracy: 0.9908 - val_loss: 0.4160 - val_accuracy: 0.8737
# Epoch 46/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9908
# Epoch 46: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 84s 28s/step - loss: 0.0365 - accuracy: 0.9908 - val_loss: 0.4528 - val_accuracy: 0.8789
# Epoch 47/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9921
# Epoch 47: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 87s 30s/step - loss: 0.0408 - accuracy: 0.9921 - val_loss: 0.4344 - val_accuracy: 0.8684
# Epoch 48/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9974
# Epoch 48: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 83s 29s/step - loss: 0.0372 - accuracy: 0.9974 - val_loss: 0.4162 - val_accuracy: 0.8789
# Epoch 49/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9908
# Epoch 49: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 83s 28s/step - loss: 0.0476 - accuracy: 0.9908 - val_loss: 0.4152 - val_accuracy: 0.8737
# Epoch 50/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.9947
# Epoch 50: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 82s 29s/step - loss: 0.0344 - accuracy: 0.9947 - val_loss: 0.4834 - val_accuracy: 0.8474
# Epoch 51/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0372 - accuracy: 0.9947
# Epoch 51: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 83s 29s/step - loss: 0.0372 - accuracy: 0.9947 - val_loss: 0.4658 - val_accuracy: 0.8842
# Epoch 52/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9960
# Epoch 52: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 84s 29s/step - loss: 0.0336 - accuracy: 0.9960 - val_loss: 0.4624 - val_accuracy: 0.8737
# Epoch 53/100
# 3/3 [==============================] - ETA: 0s - loss: 0.0324 - accuracy: 0.9960
# Epoch 53: val_accuracy did not improve from 0.90526
# 3/3 [==============================] - 84s 28s/step - loss: 0.0324 - accuracy: 0.9960 - val_loss: 0.4763 - val_accuracy: 0.8684
# Epoch 53: early stopping

# %%
saved_model = load_model('best_model.h5')

# %%
_, train_f1 = saved_model.evaluate(X_train, y_train, verbose=0)
_, test_f1 = saved_model.evaluate(X_test, y_test, verbose=0)

print(test_f1)
# Out:
# 0.9052631855010986

# %%
import matplotlib.pyplot as plt
plt.plot(m.history['accuracy'])
plt.plot(m.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
y_test1=np.argmax(y_test, axis=1)

y_pred_saved = saved_model.predict(X_test)
y_pred_saved=np.argmax(y_pred_saved,axis=1)
# Out:
# 6/6 [==============================] - 7s 1s/step

# %%
from sklearn import metrics
print(metrics.classification_report(y_test1,y_pred_saved))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.82      0.90        11
#            1       0.88      0.78      0.82         9
#            2       1.00      1.00      1.00        10
#            3       0.88      0.88      0.88         8
#            4       1.00      0.71      0.83         7
#            5       1.00      0.67      0.80         9
#            6       0.70      1.00      0.82         7
#            7       1.00      1.00      1.00        10
#            8       0.70      0.88      0.78         8
#            9       0.82      0.90      0.86        10
#           10       0.92      1.00      0.96        11
#           11       0.92      1.00      0.96        12
#           12       0.67      0.86      0.75         7
#           13       1.00      1.00      1.00         9
#           14       1.00      0.86      0.92        14
#           15       1.00      1.00      1.00        16
#           16       1.00      0.86      0.92         7
#           17       0.67      1.00      0.80         4
#           18       0.83      0.71      0.77         7
#           19       1.00      1.00      1.00        14
#
#     accuracy                           0.91       190
#    macro avg       0.90      0.90      0.89       190
# weighted avg       0.92      0.91      0.91       190

# %%
plt.plot(m.history['loss'])
plt.plot(m.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
